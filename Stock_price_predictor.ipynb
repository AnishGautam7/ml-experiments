# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import yfinance as yf

# %%
# Out:
# Enter the Code of the Stock:  d

# %%
stocks = input('Enter the Code of the Stock: ')
df = yf.download(stocks,'2008-01-01','2021-01-18', auto_adjust=True )
df.head()
# Out:
# Enter the Code of the Stock:  h
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open    Volume
# Ticker              H          H          H          H         H
# Date
# 2009-11-05  27.191154  27.443644  25.006151  26.220042  19384900
# 2009-11-06  27.191154  29.618936  26.938665  27.074620   2698600
# 2009-11-09  28.065155  28.249667  27.171731  27.375666   1886200
# 2009-11-10  28.453598  29.036266  27.657286  28.162265    813700
# 2009-11-11  28.395330  28.647820  27.686419  28.191398   1290300

# %%
df.shape
# Out:
# (2818, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2818 entries, 2009-11-05 to 2021-01-15
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   (Close, H)   2818 non-null   float64
#  1   (High, H)    2818 non-null   float64
#  2   (Low, H)     2818 non-null   float64
#  3   (Open, H)    2818 non-null   float64
#  4   (Volume, H)  2818 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 132.1 KB

# %%
data.describe()
# Out:
# Price         Close         High          Low         Open        Volume
# Ticker            G            G            G            G             G
# count   3284.000000  3284.000000  3284.000000  3284.000000  3.284000e+03
# mean      19.905040    20.104335    19.693981    19.900254  7.906435e+05
# std        8.947723     9.003546     8.904219     8.954601  7.442542e+05
# min        5.089971     5.507445     5.057859     5.186312  2.760000e+04
# 25%       12.540784    12.687426    12.360226    12.514807  4.211500e+05
# 50%       17.467208    17.590568    17.289016    17.439793  6.340000e+05
# 75%       26.028015    26.234589    25.865050    26.039648  9.541000e+05
# max       42.119858    42.363544    42.063625    42.213585  2.315070e+07

# %%
df.Close.plot(figsize=(10,7),color='r')
plt.ylabel('{}'.format(stocks))
plt.xlabel('{}'.format(stocks))
plt.show()

# %%
sns.distplot(df['Close'])
plt.show()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_8844\2820872580.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Close'])

# %%
sns.distplot(df['High'])
plt.show()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_8844\147865866.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['High'])

# %% [markdown]
# # Conclusion
#  - Shape of our data
#  - how our data is distriuted
#  - It's very non linear(non-predictable)

# %%
X= df.drop('Close', axis = 1 )

# %%
y= df['Close']
